# %% [markdown]
# # 🤖 เทรน G1 บน Google Colab — ได้โมเดลจริงไปใช้งาน
#
# notebook นี้ **ต่างจาก** `explore_g1_*.ipynb` ตรงที่มัน **เทรนจริง** แล้ว
# ได้ไฟล์โมเดล (`.pt`) ที่เอาไปใช้สั่งหุ่นได้
#
# | | explore_g1_* | train_g1_colab (อันนี้) |
# |---|---|---|
# | ทำอะไร | ดู MDP เฉยๆ | **เทรน policy จริง** |
# | ที่รัน | Mac (CPU) | **Colab (GPU ฟรี)** |
# | ได้อะไร | ความเข้าใจ | **ไฟล์โมเดล .pt** |
#
# **⚠️ ก่อนเริ่ม:** ไปที่เมนู `Runtime → Change runtime type → T4 GPU`
# ให้แน่ใจว่าใช้ GPU ไม่งั้นจะช้ามาก
#
# **หลักการ RL โดยย่อ:** เราให้ policy (neural network) ลองสั่ง action ในโลก
# จำลองหลายพันตัวขนานกัน → วัด reward → อัลกอริทึม **PPO** ปรับ network ให้ได้
# reward สูงขึ้น → วนซ้ำหลายรอบ (iteration) จน policy 'เก่ง'

# %% [markdown]
# ## 1) ตรวจว่ามี GPU
#
# ถ้าบรรทัดล่างไม่ขึ้นชื่อ GPU (เช่น Tesla T4) ให้กลับไปตั้ง Runtime ก่อน

# %%
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB

# %% [markdown]
# ## 2) ติดตั้ง mjlab
#
# clone repo แล้วติดตั้งแบบ editable (`-e`) จะได้แก้โค้ด/เพิ่ม task ได้
# (ใช้เวลาสักครู่)

# %%
# clone repo
# !if [ ! -d 'mjlab-custom' ]; then git clone -q https://github.com/anunpanya9/mjlab-custom.git; fi
# %cd /content/mjlab-custom

import os
import sys

# ติดตั้ง uv (pip ธรรมดาอ่าน [tool.uv.sources] ของ mjlab ไม่ได้ → ลง deps ไม่ครบ)
# !curl -LsSf https://astral.sh/uv/install.sh | sh
UV = "/usr/local/bin/uv"

# สำคัญ: ลงเข้า Python 'ตัวเดียวกับที่ kernel นี้ใช้' (sys.executable)
# ไม่งั้น uv จะลงเข้า /usr แล้ว kernel มองไม่เห็น → No module named mjlab
# !{UV} pip install --python {sys.executable} -e . --index-strategy unsafe-best-match

# Add current directory's src folder to sys.path to ensure mjlab is found after editable install
sys.path.insert(0, os.path.join(os.getcwd(), 'src'))

# ยืนยัน import ได้ (ไม่ต้อง restart)
import mjlab

print("✓ ติดตั้ง mjlab เข้า", sys.executable, "— import ได้เลย")
# Out:
# /content/mjlab-custom
# downloading uv 0.12.12 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# Using Python 3.13.15 environment at: /usr
# Resolved 123 packages in 1.11s
# Prepared 30 packages in 3.91s
# Uninstalled 2 packages in 70ms
# Installed 30 packages in 367ms
#  + bcrypt==5.0.0
#  - decorator==4.4.2
#  + decorator==5.3.1
#  + deprecated==1.3.1
#  + fabric==3.2.3
#  + gitdb==4.0.12
#  + gitpython==3.1.62
#  + glfw==2.10.2
#  + invoke==2.2.1
#  + jedi==0.20.0
#  + mediapy==1.2.7
#  + mjlab==1.6.0 (from file:///content/mjlab-custom)
#  + mjviser==0.0.14
#  + msgspec==0.21.1
#  + mujoco==3.11.0
#  + mujoco-warp==3.11.0
#  + onnx==1.22.0
#  + onnx-ir==1.0.0
#  + onnxscript==0.7.2
#  + paramiko==5.0.0
#  - pillow==11.3.0
#  + pillow==12.3.0
#  + pynacl==1.6.2
#  + pyvers==0.2.3
#  + rsl-rl-lib==5.5.0
#  + smmap==5.0.3
#  + tensordict==0.14.2
#  + torchrunx==0.4.0
#  + trimesh==4.12.2
#  + tyro==1.0.16
#  + viser==1.1.0
#  + warp-lang==1.17.0
# ✓ ติดตั้ง mjlab เข้า /usr/bin/python3 — import ได้เลย

# %% [markdown]
# ## 3) ปิด Weights & Biases (ให้เทรนได้เลยไม่ต้อง login)
#
# mjlab ใช้ W&B log การเทรน. ตั้ง offline เพื่อข้ามการ login (ผลเทรนยังเซฟใน
# เครื่องปกติ). ถ้าอยากดู dashboard ออนไลน์ ให้ `!wandb login` แทน

# %%
# !wandb offline
# Out:
# wandb: Updated settings file /content/mjlab-custom/wandb/settings
# W&B offline. Running your script from this directory will only write metadata locally. Use `wandb disabled` to completely turn off W&B.

# %% [markdown]
# ## 4) เทรน! (นี่คือหัวใจ)
#
# **คำสั่งเดียวจบ:** เรียก train script พร้อมพารามิเตอร์:
# - `Mjlab-Velocity-Flat-Unitree-G1` — task ที่จะเทรน (G1 เดินตามคำสั่ง)
# - `--env.scene.num-envs 2048` — จำลอง 2048 ตัวขนาน (ยิ่งเยอะยิ่งเรียนเร็ว
#   แต่กิน VRAM; T4 ไหว ~2048–4096)
# - `--agent.max-iterations 300` — เทรน 300 รอบ **(ตัวอย่างให้เห็นผลไว ~10-20
#   นาที)**. ผลจริงจังใช้ 3000+ รอบ (เดินสวยขึ้นมาก แต่นานขึ้น)
# - `--agent.save-interval 50` — เซฟ checkpoint ทุก 50 รอบ
#
# **ระหว่างเทรน** ดูค่า `Mean reward` ใน log — ควร**ค่อยๆ เพิ่มขึ้น** นั่นคือ
# สัญญาณว่า policy กำลังเรียนรู้ที่จะเดินตามคำสั่ง

# %% [markdown]
# ## 4) เทรน G1 เดิน! (10,000 รอบ)
#
# **การเดินยากกว่ายืน** — ต้องเทรนนานถึงจะเดินสวย ตั้งไว้ 10,000 รอบ
#
# - `--env.scene.num-envs 2048` — 2048 ตัวขนาน (T4 ไหว)
# - `--agent.max-iterations 10000` — เดินสวย (~1-2 ชม. บน T4)
# - `--agent.save-interval 200` — เซฟทุก 200 รอบ ลง **Drive**
# - `--log-root $LOG_ROOT_ENV` — เซฟเข้า Google Drive (กัน session หลุด)
#
# **ดู `Mean reward` เพิ่มขึ้นเรื่อยๆ** = หุ่นเรียนรู้ที่จะเดิน
#
# > ระหว่างเทรน อย่าปิดแท็บ/อย่าให้เครื่องหลับ. ถ้า session หลุด checkpoint
# > ล่าสุดยังอยู่บน Drive — ดาวน์โหลดไปใช้ได้เลย

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# โฟลเดอร์เก็บผลเทรนบน Drive
LOG_ROOT = '/content/drive/MyDrive/mjlab_logs'
os.makedirs(LOG_ROOT, exist_ok=True)
print('checkpoint จะเซฟที่:', LOG_ROOT)
# Out:
# Mounted at /content/drive
# checkpoint จะเซฟที่: /content/drive/MyDrive/mjlab_logs

# %%
import os
import torch
import sys

os.environ['LOG_ROOT_ENV'] = LOG_ROOT

if not torch.cuda.is_available():
    print("ERROR: No GPU detected. Please ensure your Colab runtime type is set to GPU (e.g., T4 GPU).")
    print("Go to 'Runtime' -> 'Change runtime type' and select a GPU accelerator.")
    sys.exit(1)

# !python -m mjlab.scripts.train Mjlab-Velocity-Flat-Unitree-G1 \
    --env.scene.num-envs 2048 \
    --agent.max-iterations 3000 \
    --agent.save-interval 200 \
    --agent.logger tensorboard \
    --log-root $LOG_ROOT_ENV
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0035
#         Episode_Metrics/mean_action_acc: 0.6186
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5645
#             Metrics/twist/error_vel_yaw: 1.0265
#            Episode_Termination/time_out: 2.6316
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.53s
#                            Time elapsed: 1:17:40
#                                     ETA: 0:02:50
#
# ################################################################################
#                           Learning iteration 2894/3000
#
#                             Total steps: 142295040
#                        Steps per second: 31669
#                         Collection time: 1.273s
#                           Learning time: 0.279s
#                         Mean value loss: 0.0227
#                     Mean surrogate loss: -0.0129
#                       Mean entropy loss: 7.6640
#                             Mean reward: 61.51
#                     Mean episode length: 996.39
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1200
#                Metrics/peak_height_mean: 0.0253
#              Metrics/slip_velocity_mean: 0.1653
#              Metrics/landing_force_mean: 293.5389
#    Episode_Reward/track_linear_velocity: 1.5416
#   Episode_Reward/track_angular_velocity: 0.9301
#                  Episode_Reward/upright: 0.9725
#                     Episode_Reward/pose: 0.6924
#             Episode_Reward/body_ang_vel: -0.0218
#         Episode_Reward/angular_momentum: -0.0333
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8095
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1644
#        Episode_Reward/foot_swing_height: -0.0252
#                Episode_Reward/foot_slip: -0.0141
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0045
#         Episode_Metrics/mean_action_acc: 0.6229
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5802
#             Metrics/twist/error_vel_yaw: 1.0237
#            Episode_Termination/time_out: 2.5714
#           Episode_Termination/fell_over: 0.0476
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:17:42
#                                     ETA: 0:02:49
#
# ################################################################################
#                           Learning iteration 2895/3000
#
#                             Total steps: 142344192
#                        Steps per second: 31166
#                         Collection time: 1.304s
#                           Learning time: 0.273s
#                         Mean value loss: 0.0215
#                     Mean surrogate loss: -0.0106
#                       Mean entropy loss: 7.6754
#                             Mean reward: 61.27
#                     Mean episode length: 994.06
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1260
#                Metrics/peak_height_mean: 0.0256
#              Metrics/slip_velocity_mean: 0.1667
#              Metrics/landing_force_mean: 293.7428
#    Episode_Reward/track_linear_velocity: 1.5433
#   Episode_Reward/track_angular_velocity: 0.9267
#                  Episode_Reward/upright: 0.9728
#                     Episode_Reward/pose: 0.7023
#             Episode_Reward/body_ang_vel: -0.0218
#         Episode_Reward/angular_momentum: -0.0337
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8073
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1655
#        Episode_Reward/foot_swing_height: -0.0275
#                Episode_Reward/foot_slip: -0.0147
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0037
#         Episode_Metrics/mean_action_acc: 0.6223
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5767
#             Metrics/twist/error_vel_yaw: 1.0281
#            Episode_Termination/time_out: 2.0435
#           Episode_Termination/fell_over: 0.0435
# --------------------------------------------------------------------------------
#                          Iteration time: 1.58s
#                            Time elapsed: 1:17:43
#                                     ETA: 0:02:47
#
# ################################################################################
#                           Learning iteration 2896/3000
#
#                             Total steps: 142393344
#                        Steps per second: 31455
#                         Collection time: 1.282s
#                           Learning time: 0.280s
#                         Mean value loss: 0.0194
#                     Mean surrogate loss: -0.0132
#                       Mean entropy loss: 7.6783
#                             Mean reward: 61.79
#                     Mean episode length: 997.67
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1292
#                Metrics/peak_height_mean: 0.0250
#              Metrics/slip_velocity_mean: 0.1641
#              Metrics/landing_force_mean: 291.8738
#    Episode_Reward/track_linear_velocity: 1.5626
#   Episode_Reward/track_angular_velocity: 0.9402
#                  Episode_Reward/upright: 0.9759
#                     Episode_Reward/pose: 0.6670
#             Episode_Reward/body_ang_vel: -0.0214
#         Episode_Reward/angular_momentum: -0.0311
#           Episode_Reward/dof_pos_limits: -0.0005
#           Episode_Reward/action_rate_l2: -0.8037
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1507
#        Episode_Reward/foot_swing_height: -0.0269
#                Episode_Reward/foot_slip: -0.0137
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0040
#         Episode_Metrics/mean_action_acc: 0.6194
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5613
#             Metrics/twist/error_vel_yaw: 1.0261
#            Episode_Termination/time_out: 2.7222
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.56s
#                            Time elapsed: 1:17:45
#                                     ETA: 0:02:45
#
# ################################################################################
#                           Learning iteration 2897/3000
#
#                             Total steps: 142442496
#                        Steps per second: 31200
#                         Collection time: 1.305s
#                           Learning time: 0.270s
#                         Mean value loss: 0.0213
#                     Mean surrogate loss: -0.0114
#                       Mean entropy loss: 7.6678
#                             Mean reward: 61.73
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1299
#                Metrics/peak_height_mean: 0.0245
#              Metrics/slip_velocity_mean: 0.1656
#              Metrics/landing_force_mean: 291.4424
#    Episode_Reward/track_linear_velocity: 1.5719
#   Episode_Reward/track_angular_velocity: 0.9311
#                  Episode_Reward/upright: 0.9773
#                     Episode_Reward/pose: 0.6490
#             Episode_Reward/body_ang_vel: -0.0211
#         Episode_Reward/angular_momentum: -0.0316
#           Episode_Reward/dof_pos_limits: -0.0007
#           Episode_Reward/action_rate_l2: -0.8066
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1515
#        Episode_Reward/foot_swing_height: -0.0238
#                Episode_Reward/foot_slip: -0.0130
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0037
#         Episode_Metrics/mean_action_acc: 0.6218
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5590
#             Metrics/twist/error_vel_yaw: 1.0359
#            Episode_Termination/time_out: 2.0455
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.58s
#                            Time elapsed: 1:17:46
#                                     ETA: 0:02:44
#
# ################################################################################
#                           Learning iteration 2898/3000
#
#                             Total steps: 142491648
#                        Steps per second: 30548
#                         Collection time: 1.328s
#                           Learning time: 0.281s
#                         Mean value loss: 0.0185
#                     Mean surrogate loss: -0.0136
#                       Mean entropy loss: 7.6659
#                             Mean reward: 61.88
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1222
#                Metrics/peak_height_mean: 0.0250
#              Metrics/slip_velocity_mean: 0.1645
#              Metrics/landing_force_mean: 292.1096
#    Episode_Reward/track_linear_velocity: 1.5600
#   Episode_Reward/track_angular_velocity: 0.9438
#                  Episode_Reward/upright: 0.9785
#                     Episode_Reward/pose: 0.6611
#             Episode_Reward/body_ang_vel: -0.0217
#         Episode_Reward/angular_momentum: -0.0314
#           Episode_Reward/dof_pos_limits: -0.0005
#           Episode_Reward/action_rate_l2: -0.8010
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1521
#        Episode_Reward/foot_swing_height: -0.0274
#                Episode_Reward/foot_slip: -0.0131
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0033
#         Episode_Metrics/mean_action_acc: 0.6197
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5724
#             Metrics/twist/error_vel_yaw: 1.0193
#            Episode_Termination/time_out: 2.7727
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.61s
#                            Time elapsed: 1:17:48
#                                     ETA: 0:02:42
#
# ################################################################################
#                           Learning iteration 2899/3000
#
#                             Total steps: 142540800
#                        Steps per second: 29415
#                         Collection time: 1.389s
#                           Learning time: 0.282s
#                         Mean value loss: 0.0208
#                     Mean surrogate loss: -0.0134
#                       Mean entropy loss: 7.6727
#                             Mean reward: 61.95
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1143
#                Metrics/peak_height_mean: 0.0245
#              Metrics/slip_velocity_mean: 0.1654
#              Metrics/landing_force_mean: 289.0113
#    Episode_Reward/track_linear_velocity: 1.5660
#   Episode_Reward/track_angular_velocity: 0.9418
#                  Episode_Reward/upright: 0.9765
#                     Episode_Reward/pose: 0.6952
#             Episode_Reward/body_ang_vel: -0.0211
#         Episode_Reward/angular_momentum: -0.0310
#           Episode_Reward/dof_pos_limits: -0.0005
#           Episode_Reward/action_rate_l2: -0.8109
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1600
#        Episode_Reward/foot_swing_height: -0.0281
#                Episode_Reward/foot_slip: -0.0163
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0029
#         Episode_Metrics/mean_action_acc: 0.6215
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5581
#             Metrics/twist/error_vel_yaw: 1.0244
#            Episode_Termination/time_out: 2.2273
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.67s
#                            Time elapsed: 1:17:50
#                                     ETA: 0:02:41
#
# ################################################################################
#                           Learning iteration 2900/3000
#
#                             Total steps: 142589952
#                        Steps per second: 28397
#                         Collection time: 1.457s
#                           Learning time: 0.274s
#                         Mean value loss: 0.0221
#                     Mean surrogate loss: -0.0135
#                       Mean entropy loss: 7.6800
#                             Mean reward: 61.41
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1095
#                Metrics/peak_height_mean: 0.0246
#              Metrics/slip_velocity_mean: 0.1659
#              Metrics/landing_force_mean: 292.7739
#    Episode_Reward/track_linear_velocity: 1.5472
#   Episode_Reward/track_angular_velocity: 0.9398
#                  Episode_Reward/upright: 0.9767
#                     Episode_Reward/pose: 0.6643
#             Episode_Reward/body_ang_vel: -0.0221
#         Episode_Reward/angular_momentum: -0.0326
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8076
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1556
#        Episode_Reward/foot_swing_height: -0.0273
#                Episode_Reward/foot_slip: -0.0137
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0036
#         Episode_Metrics/mean_action_acc: 0.6214
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5864
#             Metrics/twist/error_vel_yaw: 1.0256
#            Episode_Termination/time_out: 2.5000
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.73s
#                            Time elapsed: 1:17:51
#                                     ETA: 0:02:39
#
# ################################################################################
#                           Learning iteration 2901/3000
#
#                             Total steps: 142639104
#                        Steps per second: 31900
#                         Collection time: 1.267s
#                           Learning time: 0.274s
#                         Mean value loss: 0.0199
#                     Mean surrogate loss: -0.0134
#                       Mean entropy loss: 7.6787
#                             Mean reward: 61.88
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1110
#                Metrics/peak_height_mean: 0.0251
#              Metrics/slip_velocity_mean: 0.1664
#              Metrics/landing_force_mean: 291.3766
#    Episode_Reward/track_linear_velocity: 1.5671
#   Episode_Reward/track_angular_velocity: 0.9406
#                  Episode_Reward/upright: 0.9759
#                     Episode_Reward/pose: 0.6824
#             Episode_Reward/body_ang_vel: -0.0210
#         Episode_Reward/angular_momentum: -0.0304
#           Episode_Reward/dof_pos_limits: -0.0005
#           Episode_Reward/action_rate_l2: -0.8030
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1508
#        Episode_Reward/foot_swing_height: -0.0275
#                Episode_Reward/foot_slip: -0.0138
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0045
#         Episode_Metrics/mean_action_acc: 0.6199
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5610
#             Metrics/twist/error_vel_yaw: 1.0274
#            Episode_Termination/time_out: 2.3333
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.54s
#                            Time elapsed: 1:17:53
#                                     ETA: 0:02:37
#
# ################################################################################
#                           Learning iteration 2902/3000
#
#                             Total steps: 142688256
#                        Steps per second: 31406
#                         Collection time: 1.295s
#                           Learning time: 0.270s
#                         Mean value loss: 0.0156
#                     Mean surrogate loss: -0.0120
#                       Mean entropy loss: 7.6671
#                             Mean reward: 61.95
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0984
#                Metrics/peak_height_mean: 0.0244
#              Metrics/slip_velocity_mean: 0.1659
#              Metrics/landing_force_mean: 286.3593
#    Episode_Reward/track_linear_velocity: 1.5395
#   Episode_Reward/track_angular_velocity: 0.9391
#                  Episode_Reward/upright: 0.9776
#                     Episode_Reward/pose: 0.6890
#             Episode_Reward/body_ang_vel: -0.0219
#         Episode_Reward/angular_momentum: -0.0327
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8068
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1548
#        Episode_Reward/foot_swing_height: -0.0278
#                Episode_Reward/foot_slip: -0.0149
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0029
#         Episode_Metrics/mean_action_acc: 0.6210
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5957
#             Metrics/twist/error_vel_yaw: 1.0319
#            Episode_Termination/time_out: 2.3810
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.57s
#                            Time elapsed: 1:17:54
#                                     ETA: 0:02:36
#
# ################################################################################
#                           Learning iteration 2903/3000
#
#                             Total steps: 142737408
#                        Steps per second: 31703
#                         Collection time: 1.276s
#                           Learning time: 0.275s
#                         Mean value loss: 0.0171
#                     Mean surrogate loss: -0.0128
#                       Mean entropy loss: 7.6342
#                             Mean reward: 61.68
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1081
#                Metrics/peak_height_mean: 0.0250
#              Metrics/slip_velocity_mean: 0.1659
#              Metrics/landing_force_mean: 287.5109
#    Episode_Reward/track_linear_velocity: 1.5565
#   Episode_Reward/track_angular_velocity: 0.9372
#                  Episode_Reward/upright: 0.9762
#                     Episode_Reward/pose: 0.6749
#             Episode_Reward/body_ang_vel: -0.0222
#         Episode_Reward/angular_momentum: -0.0321
#           Episode_Reward/dof_pos_limits: -0.0006
#           Episode_Reward/action_rate_l2: -0.8046
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1530
#        Episode_Reward/foot_swing_height: -0.0268
#                Episode_Reward/foot_slip: -0.0138
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0033
#         Episode_Metrics/mean_action_acc: 0.6213
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5684
#             Metrics/twist/error_vel_yaw: 1.0309
#            Episode_Termination/time_out: 2.7619
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:17:56
#                                     ETA: 0:02:34
#
# ################################################################################
#                           Learning iteration 2904/3000
#
#                             Total steps: 142786560
#                        Steps per second: 31368
#                         Collection time: 1.295s
#                           Learning time: 0.272s
#                         Mean value loss: 0.0195
#                     Mean surrogate loss: -0.0131
#                       Mean entropy loss: 7.6202
#                             Mean reward: 61.54
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1062
#                Metrics/peak_height_mean: 0.0248
#              Metrics/slip_velocity_mean: 0.1661
#              Metrics/landing_force_mean: 286.4694
#    Episode_Reward/track_linear_velocity: 1.5471
#   Episode_Reward/track_angular_velocity: 0.9324
#                  Episode_Reward/upright: 0.9755
#                     Episode_Reward/pose: 0.6863
#             Episode_Reward/body_ang_vel: -0.0228
#         Episode_Reward/angular_momentum: -0.0350
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8103
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1661
#        Episode_Reward/foot_swing_height: -0.0259
#                Episode_Reward/foot_slip: -0.0151
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0041
#         Episode_Metrics/mean_action_acc: 0.6213
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5747
#             Metrics/twist/error_vel_yaw: 1.0346
#            Episode_Termination/time_out: 2.2381
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.57s
#                            Time elapsed: 1:17:57
#                                     ETA: 0:02:32
#
# ################################################################################
#                           Learning iteration 2905/3000
#
#                             Total steps: 142835712
#                        Steps per second: 32245
#                         Collection time: 1.252s
#                           Learning time: 0.272s
#                         Mean value loss: 0.0242
#                     Mean surrogate loss: -0.0109
#                       Mean entropy loss: 7.6248
#                             Mean reward: 61.17
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1070
#                Metrics/peak_height_mean: 0.0250
#              Metrics/slip_velocity_mean: 0.1671
#              Metrics/landing_force_mean: 288.0247
#    Episode_Reward/track_linear_velocity: 1.5318
#   Episode_Reward/track_angular_velocity: 0.9346
#                  Episode_Reward/upright: 0.9764
#                     Episode_Reward/pose: 0.6745
#             Episode_Reward/body_ang_vel: -0.0223
#         Episode_Reward/angular_momentum: -0.0318
#           Episode_Reward/dof_pos_limits: -0.0007
#           Episode_Reward/action_rate_l2: -0.8094
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1555
#        Episode_Reward/foot_swing_height: -0.0266
#                Episode_Reward/foot_slip: -0.0142
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0070
#         Episode_Metrics/mean_action_acc: 0.6214
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5975
#             Metrics/twist/error_vel_yaw: 1.0278
#            Episode_Termination/time_out: 2.1875
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.52s
#                            Time elapsed: 1:17:59
#                                     ETA: 0:02:31
#
# ################################################################################
#                           Learning iteration 2906/3000
#
#                             Total steps: 142884864
#                        Steps per second: 31802
#                         Collection time: 1.273s
#                           Learning time: 0.273s
#                         Mean value loss: 0.0241
#                     Mean surrogate loss: -0.0120
#                       Mean entropy loss: 7.6243
#                             Mean reward: 60.94
#                     Mean episode length: 992.30
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1090
#                Metrics/peak_height_mean: 0.0253
#              Metrics/slip_velocity_mean: 0.1678
#              Metrics/landing_force_mean: 289.8807
#    Episode_Reward/track_linear_velocity: 1.5477
#   Episode_Reward/track_angular_velocity: 0.9298
#                  Episode_Reward/upright: 0.9673
#                     Episode_Reward/pose: 0.6742
#             Episode_Reward/body_ang_vel: -0.0222
#         Episode_Reward/angular_momentum: -0.0324
#           Episode_Reward/dof_pos_limits: -0.0010
#           Episode_Reward/action_rate_l2: -0.8027
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1564
#        Episode_Reward/foot_swing_height: -0.0275
#                Episode_Reward/foot_slip: -0.0147
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0043
#         Episode_Metrics/mean_action_acc: 0.6215
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5634
#             Metrics/twist/error_vel_yaw: 1.0212
#            Episode_Termination/time_out: 2.2857
#           Episode_Termination/fell_over: 0.0476
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:18:01
#                                     ETA: 0:02:29
#
# ################################################################################
#                           Learning iteration 2907/3000
#
#                             Total steps: 142934016
#                        Steps per second: 29704
#                         Collection time: 1.372s
#                           Learning time: 0.282s
#                         Mean value loss: 0.0236
#                     Mean surrogate loss: -0.0131
#                       Mean entropy loss: 7.6345
#                             Mean reward: 60.70
#                     Mean episode length: 992.30
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1059
#                Metrics/peak_height_mean: 0.0251
#              Metrics/slip_velocity_mean: 0.1657
#              Metrics/landing_force_mean: 287.4655
#    Episode_Reward/track_linear_velocity: 1.5456
#   Episode_Reward/track_angular_velocity: 0.9314
#                  Episode_Reward/upright: 0.9758
#                     Episode_Reward/pose: 0.6551
#             Episode_Reward/body_ang_vel: -0.0223
#         Episode_Reward/angular_momentum: -0.0331
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8089
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1529
#        Episode_Reward/foot_swing_height: -0.0234
#                Episode_Reward/foot_slip: -0.0144
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0054
#         Episode_Metrics/mean_action_acc: 0.6207
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5910
#             Metrics/twist/error_vel_yaw: 1.0366
#            Episode_Termination/time_out: 2.0952
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.65s
#                            Time elapsed: 1:18:02
#                                     ETA: 0:02:28
#
# ################################################################################
#                           Learning iteration 2908/3000
#
#                             Total steps: 142983168
#                        Steps per second: 28616
#                         Collection time: 1.426s
#                           Learning time: 0.292s
#                         Mean value loss: 0.0294
#                     Mean surrogate loss: -0.0093
#                       Mean entropy loss: 7.6611
#                             Mean reward: 61.39
#                     Mean episode length: 994.43
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1089
#                Metrics/peak_height_mean: 0.0252
#              Metrics/slip_velocity_mean: 0.1677
#              Metrics/landing_force_mean: 289.8131
#    Episode_Reward/track_linear_velocity: 1.5567
#   Episode_Reward/track_angular_velocity: 0.9393
#                  Episode_Reward/upright: 0.9713
#                     Episode_Reward/pose: 0.6862
#             Episode_Reward/body_ang_vel: -0.0210
#         Episode_Reward/angular_momentum: -0.0314
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8004
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1553
#        Episode_Reward/foot_swing_height: -0.0297
#                Episode_Reward/foot_slip: -0.0141
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0036
#         Episode_Metrics/mean_action_acc: 0.6218
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5592
#             Metrics/twist/error_vel_yaw: 1.0202
#            Episode_Termination/time_out: 2.3182
#           Episode_Termination/fell_over: 0.0455
# --------------------------------------------------------------------------------
#                          Iteration time: 1.72s
#                            Time elapsed: 1:18:04
#                                     ETA: 0:02:26
#
# ################################################################################
#                           Learning iteration 2909/3000
#
#                             Total steps: 143032320
#                        Steps per second: 30097
#                         Collection time: 1.364s
#                           Learning time: 0.269s
#                         Mean value loss: 0.0193
#                     Mean surrogate loss: -0.0127
#                       Mean entropy loss: 7.6737
#                             Mean reward: 61.64
#                     Mean episode length: 993.10
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1004
#                Metrics/peak_height_mean: 0.0251
#              Metrics/slip_velocity_mean: 0.1678
#              Metrics/landing_force_mean: 289.9762
#    Episode_Reward/track_linear_velocity: 1.5455
#   Episode_Reward/track_angular_velocity: 0.9395
#                  Episode_Reward/upright: 0.9753
#                     Episode_Reward/pose: 0.6728
#             Episode_Reward/body_ang_vel: -0.0219
#         Episode_Reward/angular_momentum: -0.0324
#           Episode_Reward/dof_pos_limits: -0.0007
#           Episode_Reward/action_rate_l2: -0.8024
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1556
#        Episode_Reward/foot_swing_height: -0.0262
#                Episode_Reward/foot_slip: -0.0135
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0051
#         Episode_Metrics/mean_action_acc: 0.6205
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5793
#             Metrics/twist/error_vel_yaw: 1.0279
#            Episode_Termination/time_out: 2.5714
#           Episode_Termination/fell_over: 0.0952
# --------------------------------------------------------------------------------
#                          Iteration time: 1.63s
#                            Time elapsed: 1:18:06
#                                     ETA: 0:02:24
#
# ################################################################################
#                           Learning iteration 2910/3000
#
#                             Total steps: 143081472
#                        Steps per second: 32366
#                         Collection time: 1.249s
#                           Learning time: 0.269s
#                         Mean value loss: 0.0277
#                     Mean surrogate loss: -0.0109
#                       Mean entropy loss: 7.6800
#                             Mean reward: 61.97
#                     Mean episode length: 998.67
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1122
#                Metrics/peak_height_mean: 0.0250
#              Metrics/slip_velocity_mean: 0.1683
#              Metrics/landing_force_mean: 289.6766
#    Episode_Reward/track_linear_velocity: 1.5671
#   Episode_Reward/track_angular_velocity: 0.9418
#                  Episode_Reward/upright: 0.9771
#                     Episode_Reward/pose: 0.6637
#             Episode_Reward/body_ang_vel: -0.0211
#         Episode_Reward/angular_momentum: -0.0311
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8010
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1427
#        Episode_Reward/foot_swing_height: -0.0250
#                Episode_Reward/foot_slip: -0.0132
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0040
#         Episode_Metrics/mean_action_acc: 0.6197
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5605
#             Metrics/twist/error_vel_yaw: 1.0395
#            Episode_Termination/time_out: 2.2632
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.52s
#                            Time elapsed: 1:18:07
#                                     ETA: 0:02:23
#
# ################################################################################
#                           Learning iteration 2911/3000
#
#                             Total steps: 143130624
#                        Steps per second: 31327
#                         Collection time: 1.294s
#                           Learning time: 0.275s
#                         Mean value loss: 0.0212
#                     Mean surrogate loss: -0.0125
#                       Mean entropy loss: 7.6814
#                             Mean reward: 61.51
#                     Mean episode length: 992.39
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1107
#                Metrics/peak_height_mean: 0.0249
#              Metrics/slip_velocity_mean: 0.1664
#              Metrics/landing_force_mean: 285.9422
#    Episode_Reward/track_linear_velocity: 1.5317
#   Episode_Reward/track_angular_velocity: 0.9264
#                  Episode_Reward/upright: 0.9656
#                     Episode_Reward/pose: 0.6511
#             Episode_Reward/body_ang_vel: -0.0212
#         Episode_Reward/angular_momentum: -0.0322
#           Episode_Reward/dof_pos_limits: -0.0011
#           Episode_Reward/action_rate_l2: -0.7986
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1505
#        Episode_Reward/foot_swing_height: -0.0274
#                Episode_Reward/foot_slip: -0.0156
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0039
#         Episode_Metrics/mean_action_acc: 0.6214
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5723
#             Metrics/twist/error_vel_yaw: 1.0139
#            Episode_Termination/time_out: 2.0455
#           Episode_Termination/fell_over: 0.0909
# --------------------------------------------------------------------------------
#                          Iteration time: 1.57s
#                            Time elapsed: 1:18:09
#                                     ETA: 0:02:21
#
# ################################################################################
#                           Learning iteration 2912/3000
#
#                             Total steps: 143179776
#                        Steps per second: 31770
#                         Collection time: 1.278s
#                           Learning time: 0.269s
#                         Mean value loss: 0.0199
#                     Mean surrogate loss: -0.0117
#                       Mean entropy loss: 7.6737
#                             Mean reward: 60.98
#                     Mean episode length: 992.39
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0995
#                Metrics/peak_height_mean: 0.0247
#              Metrics/slip_velocity_mean: 0.1685
#              Metrics/landing_force_mean: 289.7785
#    Episode_Reward/track_linear_velocity: 1.5383
#   Episode_Reward/track_angular_velocity: 0.9298
#                  Episode_Reward/upright: 0.9768
#                     Episode_Reward/pose: 0.6791
#             Episode_Reward/body_ang_vel: -0.0220
#         Episode_Reward/angular_momentum: -0.0324
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8086
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1553
#        Episode_Reward/foot_swing_height: -0.0264
#                Episode_Reward/foot_slip: -0.0147
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0041
#         Episode_Metrics/mean_action_acc: 0.6217
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5923
#             Metrics/twist/error_vel_yaw: 1.0475
#            Episode_Termination/time_out: 2.3333
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:18:10
#                                     ETA: 0:02:20
#
# ################################################################################
#                           Learning iteration 2913/3000
#
#                             Total steps: 143228928
#                        Steps per second: 32121
#                         Collection time: 1.260s
#                           Learning time: 0.271s
#                         Mean value loss: 0.0176
#                     Mean surrogate loss: -0.0126
#                       Mean entropy loss: 7.6645
#                             Mean reward: 61.30
#                     Mean episode length: 990.72
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1185
#                Metrics/peak_height_mean: 0.0252
#              Metrics/slip_velocity_mean: 0.1662
#              Metrics/landing_force_mean: 292.5076
#    Episode_Reward/track_linear_velocity: 1.5262
#   Episode_Reward/track_angular_velocity: 0.9252
#                  Episode_Reward/upright: 0.9603
#                     Episode_Reward/pose: 0.6949
#             Episode_Reward/body_ang_vel: -0.0221
#         Episode_Reward/angular_momentum: -0.0325
#           Episode_Reward/dof_pos_limits: -0.0007
#           Episode_Reward/action_rate_l2: -0.7946
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1577
#        Episode_Reward/foot_swing_height: -0.0282
#                Episode_Reward/foot_slip: -0.0144
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0029
#         Episode_Metrics/mean_action_acc: 0.6217
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5679
#             Metrics/twist/error_vel_yaw: 1.0204
#            Episode_Termination/time_out: 2.1000
#           Episode_Termination/fell_over: 0.0500
# --------------------------------------------------------------------------------
#                          Iteration time: 1.53s
#                            Time elapsed: 1:18:12
#                                     ETA: 0:02:18
#
# ################################################################################
#                           Learning iteration 2914/3000
#
#                             Total steps: 143278080
#                        Steps per second: 31896
#                         Collection time: 1.265s
#                           Learning time: 0.276s
#                         Mean value loss: 0.0205
#                     Mean surrogate loss: -0.0124
#                       Mean entropy loss: 7.6589
#                             Mean reward: 61.57
#                     Mean episode length: 993.33
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.1109
#                Metrics/peak_height_mean: 0.0252
#              Metrics/slip_velocity_mean: 0.1700
#              Metrics/landing_force_mean: 290.7582
#    Episode_Reward/track_linear_velocity: 1.5497
#   Episode_Reward/track_angular_velocity: 0.9444
#                  Episode_Reward/upright: 0.9783
#                     Episode_Reward/pose: 0.6870
#             Episode_Reward/body_ang_vel: -0.0217
#         Episode_Reward/angular_momentum: -0.0311
#           Episode_Reward/dof_pos_limits: -0.0005
#           Episode_Reward/action_rate_l2: -0.8060
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1556
#        Episode_Reward/foot_swing_height: -0.0250
#                Episode_Reward/foot_slip: -0.0141
# ...
#
# ################################################################################
#                           Learning iteration 2993/3000
#
#                             Total steps: 147161088
#                        Steps per second: 29045
#                         Collection time: 1.400s
#                           Learning time: 0.292s
#                         Mean value loss: 0.0201
#                     Mean surrogate loss: -0.0146
#                       Mean entropy loss: 7.5260
#                             Mean reward: 62.41
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0802
#                Metrics/peak_height_mean: 0.0248
#              Metrics/slip_velocity_mean: 0.1668
#              Metrics/landing_force_mean: 285.9694
#    Episode_Reward/track_linear_velocity: 1.5544
#   Episode_Reward/track_angular_velocity: 0.9438
#                  Episode_Reward/upright: 0.9783
#                     Episode_Reward/pose: 0.7116
#             Episode_Reward/body_ang_vel: -0.0205
#         Episode_Reward/angular_momentum: -0.0299
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8002
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1606
#        Episode_Reward/foot_swing_height: -0.0275
#                Episode_Reward/foot_slip: -0.0128
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0044
#         Episode_Metrics/mean_action_acc: 0.6190
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5773
#             Metrics/twist/error_vel_yaw: 1.0316
#            Episode_Termination/time_out: 1.7222
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.69s
#                            Time elapsed: 1:20:19
#                                     ETA: 0:00:09
#
# ################################################################################
#                           Learning iteration 2994/3000
#
#                             Total steps: 147210240
#                        Steps per second: 28827
#                         Collection time: 1.433s
#                           Learning time: 0.272s
#                         Mean value loss: 0.0154
#                     Mean surrogate loss: -0.0126
#                       Mean entropy loss: 7.5109
#                             Mean reward: 62.50
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0692
#                Metrics/peak_height_mean: 0.0247
#              Metrics/slip_velocity_mean: 0.1678
#              Metrics/landing_force_mean: 289.8606
#    Episode_Reward/track_linear_velocity: 1.5557
#   Episode_Reward/track_angular_velocity: 0.9434
#                  Episode_Reward/upright: 0.9774
#                     Episode_Reward/pose: 0.7082
#             Episode_Reward/body_ang_vel: -0.0202
#         Episode_Reward/angular_momentum: -0.0314
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8032
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1676
#        Episode_Reward/foot_swing_height: -0.0293
#                Episode_Reward/foot_slip: -0.0161
#             Episode_Reward/soft_landing: -0.0006
#          Episode_Reward/self_collisions: -0.0039
#         Episode_Metrics/mean_action_acc: 0.6189
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5681
#             Metrics/twist/error_vel_yaw: 1.0187
#            Episode_Termination/time_out: 2.4091
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.71s
#                            Time elapsed: 1:20:21
#                                     ETA: 0:00:08
#
# ################################################################################
#                           Learning iteration 2995/3000
#
#                             Total steps: 147259392
#                        Steps per second: 31275
#                         Collection time: 1.296s
#                           Learning time: 0.275s
#                         Mean value loss: 0.0227
#                     Mean surrogate loss: -0.0113
#                       Mean entropy loss: 7.4871
#                             Mean reward: 62.28
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0826
#                Metrics/peak_height_mean: 0.0252
#              Metrics/slip_velocity_mean: 0.1704
#              Metrics/landing_force_mean: 289.0585
#    Episode_Reward/track_linear_velocity: 1.5484
#   Episode_Reward/track_angular_velocity: 0.9434
#                  Episode_Reward/upright: 0.9784
#                     Episode_Reward/pose: 0.7009
#             Episode_Reward/body_ang_vel: -0.0204
#         Episode_Reward/angular_momentum: -0.0308
#           Episode_Reward/dof_pos_limits: -0.0009
#           Episode_Reward/action_rate_l2: -0.8082
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1618
#        Episode_Reward/foot_swing_height: -0.0291
#                Episode_Reward/foot_slip: -0.0170
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0041
#         Episode_Metrics/mean_action_acc: 0.6207
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5790
#             Metrics/twist/error_vel_yaw: 1.0232
#            Episode_Termination/time_out: 2.3636
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.57s
#                            Time elapsed: 1:20:23
#                                     ETA: 0:00:06
#
# ################################################################################
#                           Learning iteration 2996/3000
#
#                             Total steps: 147308544
#                        Steps per second: 31350
#                         Collection time: 1.296s
#                           Learning time: 0.272s
#                         Mean value loss: 0.0186
#                     Mean surrogate loss: -0.0126
#                       Mean entropy loss: 7.4822
#                             Mean reward: 61.29
#                     Mean episode length: 993.14
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0843
#                Metrics/peak_height_mean: 0.0256
#              Metrics/slip_velocity_mean: 0.1690
#              Metrics/landing_force_mean: 291.0908
#    Episode_Reward/track_linear_velocity: 1.5083
#   Episode_Reward/track_angular_velocity: 0.9270
#                  Episode_Reward/upright: 0.9685
#                     Episode_Reward/pose: 0.6866
#             Episode_Reward/body_ang_vel: -0.0205
#         Episode_Reward/angular_momentum: -0.0326
#           Episode_Reward/dof_pos_limits: -0.0011
#           Episode_Reward/action_rate_l2: -0.8045
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1688
#        Episode_Reward/foot_swing_height: -0.0268
#                Episode_Reward/foot_slip: -0.0164
#             Episode_Reward/soft_landing: -0.0006
#          Episode_Reward/self_collisions: -0.0044
#         Episode_Metrics/mean_action_acc: 0.6211
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.6081
#             Metrics/twist/error_vel_yaw: 1.0134
#            Episode_Termination/time_out: 2.1429
#           Episode_Termination/fell_over: 0.0476
# --------------------------------------------------------------------------------
#                          Iteration time: 1.57s
#                            Time elapsed: 1:20:24
#                                     ETA: 0:00:04
#
# ################################################################################
#                           Learning iteration 2997/3000
#
#                             Total steps: 147357696
#                        Steps per second: 31707
#                         Collection time: 1.275s
#                           Learning time: 0.275s
#                         Mean value loss: 0.0198
#                     Mean surrogate loss: -0.0133
#                       Mean entropy loss: 7.4801
#                             Mean reward: 61.51
#                     Mean episode length: 993.14
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0856
#                Metrics/peak_height_mean: 0.0256
#              Metrics/slip_velocity_mean: 0.1688
#              Metrics/landing_force_mean: 288.8023
#    Episode_Reward/track_linear_velocity: 1.5648
#   Episode_Reward/track_angular_velocity: 0.9470
#                  Episode_Reward/upright: 0.9795
#                     Episode_Reward/pose: 0.7116
#             Episode_Reward/body_ang_vel: -0.0203
#         Episode_Reward/angular_momentum: -0.0287
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.7972
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1544
#        Episode_Reward/foot_swing_height: -0.0259
#                Episode_Reward/foot_slip: -0.0135
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0044
#         Episode_Metrics/mean_action_acc: 0.6176
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5716
#             Metrics/twist/error_vel_yaw: 1.0276
#            Episode_Termination/time_out: 2.2778
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:20:26
#                                     ETA: 0:00:03
#
# ################################################################################
#                           Learning iteration 2998/3000
#
#                             Total steps: 147406848
#                        Steps per second: 31731
#                         Collection time: 1.274s
#                           Learning time: 0.275s
#                         Mean value loss: 0.0188
#                     Mean surrogate loss: -0.0133
#                       Mean entropy loss: 7.4718
#                             Mean reward: 61.57
#                     Mean episode length: 993.14
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0800
#                Metrics/peak_height_mean: 0.0253
#              Metrics/slip_velocity_mean: 0.1675
#              Metrics/landing_force_mean: 287.8833
#    Episode_Reward/track_linear_velocity: 1.5467
#   Episode_Reward/track_angular_velocity: 0.9371
#                  Episode_Reward/upright: 0.9781
#                     Episode_Reward/pose: 0.6926
#             Episode_Reward/body_ang_vel: -0.0198
#         Episode_Reward/angular_momentum: -0.0315
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8035
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1669
#        Episode_Reward/foot_swing_height: -0.0260
#                Episode_Reward/foot_slip: -0.0139
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0036
#         Episode_Metrics/mean_action_acc: 0.6204
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5798
#             Metrics/twist/error_vel_yaw: 1.0294
#            Episode_Termination/time_out: 2.1176
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.55s
#                            Time elapsed: 1:20:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                           Learning iteration 2999/3000
#
#                             Total steps: 147456000
#                        Steps per second: 31557
#                         Collection time: 1.282s
#                           Learning time: 0.276s
#                         Mean value loss: 0.0224
#                     Mean surrogate loss: -0.0125
#                       Mean entropy loss: 7.4658
#                             Mean reward: 62.37
#                     Mean episode length: 1000.00
#                         Mean action std: 0.36
#           Metrics/angular_momentum_mean: 1.0808
#                Metrics/peak_height_mean: 0.0255
#              Metrics/slip_velocity_mean: 0.1668
#              Metrics/landing_force_mean: 286.4415
#    Episode_Reward/track_linear_velocity: 1.5653
#   Episode_Reward/track_angular_velocity: 0.9435
#                  Episode_Reward/upright: 0.9789
#                     Episode_Reward/pose: 0.6892
#             Episode_Reward/body_ang_vel: -0.0202
#         Episode_Reward/angular_momentum: -0.0306
#           Episode_Reward/dof_pos_limits: -0.0008
#           Episode_Reward/action_rate_l2: -0.8019
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1567
#        Episode_Reward/foot_swing_height: -0.0266
#                Episode_Reward/foot_slip: -0.0142
#             Episode_Reward/soft_landing: -0.0005
#          Episode_Reward/self_collisions: -0.0045
#         Episode_Metrics/mean_action_acc: 0.6191
#    Curriculum/command_vel/lin_vel_x_min: -1.0000
#    Curriculum/command_vel/lin_vel_x_max: 1.0000
#    Curriculum/command_vel/lin_vel_y_min: -1.0000
#    Curriculum/command_vel/lin_vel_y_max: 1.0000
#    Curriculum/command_vel/ang_vel_z_min: -0.5000
#    Curriculum/command_vel/ang_vel_z_max: 0.5000
#              Metrics/twist/error_vel_xy: 0.5628
#             Metrics/twist/error_vel_yaw: 1.0239
#            Episode_Termination/time_out: 2.5500
#           Episode_Termination/fell_over: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 1.56s
#                            Time elapsed: 1:20:29
#                                     ETA: 0:00:00

# %% [markdown]
# ## 5) หา checkpoint ที่เทรนได้ (ไฟล์โมเดล .pt)
#
# mjlab เซฟ checkpoint ที่ `logs/rsl_rl/<experiment_name>/<run>/`. สำหรับ G1
# velocity ชื่อ experiment คือ `g1_velocity`. เราหา run ล่าสุดและ checkpoint
# รอบสูงสุด

# %%
import os
from pathlib import Path

# checkpoint อยู่บน Google Drive (จาก --log-root)
log_dir = Path(LOG_ROOT) / 'g1_velocity'
runs = sorted(log_dir.glob('*'), key=os.path.getmtime, reverse=True)
assert runs, 'ไม่พบ run บน Drive — เทรนสำเร็จหรือยัง?'
latest = runs[0]
ckpts = sorted(latest.glob('model_*.pt'),
               key=lambda p: int(''.join(filter(str.isdigit, p.stem))))
checkpoint = str(ckpts[-1])
print('run:', latest.name)
print('checkpoints ล่าสุด:', [c.name for c in ckpts[-3:]])
print('✅ โมเดล:', checkpoint)
print('   (เซฟบน Google Drive แล้ว)')
# Out:
# run: 2026-09-10_09-03-32
# checkpoints ล่าสุด: ['model_2600.pt', 'model_2800.pt', 'model_2999.pt']
# ✅ โมเดล: /content/drive/MyDrive/mjlab_logs/g1_velocity/2026-09-10_09-03-32/model_2999.pt
#    (เซฟบน Google Drive แล้ว)

# %% [markdown]
# ## 6) ทดสอบโมเดล — ให้ policy ที่เทรนแล้วสั่งหุ่น แล้วอัดวิดีโอ
#
# **แนวคิด:** โหลด checkpoint กลับเข้ามาเป็น policy แล้วให้มันสั่งหุ่นจริง (ไม่ใช่
# random แล้ว!) เราเรนเดอร์ทีละเฟรมเองเป็นวิดีโอ — วิธีนี้ควบคุมได้เต็มที่และ
# **ไม่ค้าง** (ไม่เปิด viewer ที่ Colab ไม่มีจอ)
#
# > ตั้ง `MUJOCO_GL=egl` เพื่อเรนเดอร์แบบ headless (ไม่ต้องมีจอ) — ต้องตั้ง
# > **ก่อน** import mujoco/สร้าง env ครั้งแรก

# %%
os.environ["MUJOCO_GL"] = "egl"  # headless render บน Colab

from dataclasses import asdict

import imageio
import torch

import mjlab.tasks  # noqa: F401
from mjlab.envs import ManagerBasedRlEnv
from mjlab.rl import RslRlVecEnvWrapper
from mjlab.rl.runner import MjlabOnPolicyRunner
from mjlab.tasks.registry import load_env_cfg, load_rl_cfg, load_runner_cls

TASK = "Mjlab-Velocity-Flat-Unitree-G1"
device = "cuda" if torch.cuda.is_available() else "cpu"

# สร้าง env แบบ play (1 ตัว) พร้อม render_mode
env_cfg = load_env_cfg(TASK, play=True)
env_cfg.scene.num_envs = 1
eval_env = ManagerBasedRlEnv(cfg=env_cfg, device=device, render_mode="rgb_array")

# โหลด policy จาก checkpoint
agent_cfg = load_rl_cfg(TASK)
runner_cls = load_runner_cls(TASK) or MjlabOnPolicyRunner
wrapped = RslRlVecEnvWrapper(eval_env, clip_actions=agent_cfg.clip_actions)
runner = runner_cls(wrapped, asdict(agent_cfg), device=device)
runner.load(checkpoint, load_cfg={"actor": True}, strict=True, map_location=device)
policy = runner.get_inference_policy(device=device)
print("✓ โหลด policy จาก", Path(checkpoint).name)
# Out:
# Warp 1.17.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.0
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "Tesla T4" (15 GiB, sm_75, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.17.0
# Module mujoco_warp._src.smooth b9cc505 load on device 'cuda:0' took 4.54 ms  (cached)
# Module _nxn_broadphase__locals__kernel_3a0c7ab9 3a0c7ab load on device 'cuda:0' took 0.81 ms  (cached)
# Module _primitive_narrowphase__locals__primitive_narrowphase_8d707f29 8d707f2 load on device 'cuda:0' took 1.16 ms  (cached)
# Module mujoco_warp._src.constraint 9435a53 load on device 'cuda:0' took 0.59 ms  (cached)
# Module _friction_dof__locals__kernel_85239eb5 85239eb load on device 'cuda:0' took 0.95 ms  (cached)
# Module _limit_slide_hinge__locals__kernel_b8014c9f b8014c9 load on device 'cuda:0' took 0.77 ms  (cached)
# Module _efc_contact_init__locals__kernel_34eca94d 34eca94 load on device 'cuda:0' took 0.69 ms  (cached)
# Module _efc_contact_jac_sparse__locals__kernel_eb752226 eb75222 load on device 'cuda:0' took 0.70 ms  (cached)
# Module _efc_contact_update__locals__kernel_1a7e7f98 1a7e7f9 load on device 'cuda:0' took 0.71 ms  (cached)
# Module mujoco_warp._src.sensor 764597f load on device 'cuda:0' took 4.12 ms  (cached)
# Module mujoco_warp._src.forward f44d3e1 load on device 'cuda:0' took 1.62 ms  (cached)
# Module mujoco_warp._src.passive 80f3681 load on device 'cuda:0' took 2.52 ms  (cached)
# Module mujoco_warp._src.forward 0a75030 load on device 'cuda:0' took 1.73 ms  (cached)
# Module _qfrc_smooth__locals__kernel_2c4e0694 2c4e069 load on device 'cuda:0' took 0.61 ms  (cached)
# Module mujoco_warp._src.support f39c2de load on device 'cuda:0' took 0.73 ms  (cached)
# Module _tile_cholesky_factorize_solve_block__locals__kernel_b778dc3e bc43cde load on device 'cuda:0' took 62.69 ms  (cached)
# Module _solve_init_dof__locals__kernel_48710307 4871030 load on device 'cuda:0' took 0.69 ms  (cached)
# Module mujoco_warp._src.solver c97221b load on device 'cuda:0' took 2.52 ms  (cached)
# Module _solve_init_jaref_kernel__locals__kernel_74704859 7470485 load on device 'cuda:0' took 0.69 ms  (cached)
# Module mul_m_kernel__locals___mul_m_74986a16 74986a1 load on device 'cuda:0' took 0.66 ms  (cached)
# Module _update_constraint_efc__locals__kernel_ed085732 ed08573 load on device 'cuda:0' took 0.65 ms  (cached)
# Module _update_constraint_init_qfrc_constraint_sparse__locals__kernel_67d0743a 67d0743 load on device 'cuda:0' took 0.91 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_ada3cc5f ada3cc5 load on device 'cuda:0' took 0.64 ms  (cached)
# Module _update_gradient_grad__locals__kernel_45d59ec9 45d59ec load on device 'cuda:0' took 0.63 ms  (cached)
# Module _update_gradient_init_h_sparse__locals__kernel_3d60cf50 3d60cf5 load on device 'cuda:0' took 0.64 ms  (cached)
# Module _JTDAJ_sparse__locals__kernel_eac33f90 eac33f9 load on device 'cuda:0' took 0.67 ms  (cached)
# Module _JTDAJ_sparse__locals__kernel_eac33f90 afcc61a load on device 'cuda:0' took 0.69 ms  (cached)
# Module _update_gradient_cholesky_blocked__locals__kernel_35012c43 a909dc4 load on device 'cuda:0' took 130.92 ms  (cached)
# Module _linesearch_jv_fused_kernel__locals__kernel_56b94d31 56b94d3 load on device 'cuda:0' took 0.86 ms  (cached)
# Module _linesearch_iterative_kernel__locals__kernel_98b213aa 846f43e load on device 'cuda:0' took 1.22 ms  (cached)
# Module _update_constraint_efc__locals__kernel_b09277e7 b09277e load on device 'cuda:0' took 0.76 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_90b73b32 90b73b3 load on device 'cuda:0' took 0.75 ms  (cached)
# Module _update_gradient_grad__locals__kernel_89d63404 89d6340 load on device 'cuda:0' took 0.64 ms  (cached)
# Module _update_gradient_h_incremental_sparse__locals__kernel_8510a60f 8510a60 load on device 'cuda:0' took 0.73 ms  (cached)
# Module _update_gradient_cholesky_blocked_skip_unchanged__locals__kernel_36d4650f 892ee7e load on device 'cuda:0' took 152.07 ms  (cached)
# Module _contact_sort__locals__contact_sort_adeecb09 788a659 load on device 'cuda:0' took 1.00 ms  (cached)
# Module mujoco_warp._src.derivative 1d93a53 load on device 'cuda:0' took 2.00 ms  (cached)
# Module _next_time_builder__locals___next_time_cc50a46c cc50a46 load on device 'cuda:0' took 0.86 ms  (cached)
# Module reset_data__locals__reset_xfrc_applied_c7eeecfb c7eeecf load on device 'cuda:0' took 0.78 ms  (cached)
# Module reset_data__locals__reset_M_d1ea7a8e d1ea7a8 load on device 'cuda:0' took 0.62 ms  (cached)
# Module reset_data__locals__reset_mocap_b017f38a b017f38 load on device 'cuda:0' took 0.63 ms  (cached)
# Module reset_data__locals__reset_contact_757d9bde 757d9bd load on device 'cuda:0' took 0.66 ms  (cached)
# Module reset_data__locals__reset_sleep_6b3be194 6b3be19 load on device 'cuda:0' took 0.67 ms  (cached)
# Module reset_data__locals__reset_nworld_e471a890 e471a89 load on device 'cuda:0' took 0.91 ms  (cached)
# Module mujoco_warp._src.render_util 9978d2d load on device 'cuda:0' took 1.10 ms  (cached)
# Module mujoco_warp._src.bvh 7dab8b4 load on device 'cuda:0' took 1.68 ms  (cached)
# Module mujoco_warp._src.ray cba3709 load on device 'cuda:0' took 2.11 ms  (cached)
#
# +--------------------------------+
# |        Base Environment        |
# +------------------------+-------+
# | Property               | Value |
# +------------------------+-------+
# | Number of environments | 1     |
# | Environment device     | cuda  |
# | Environment seed       | None  |
# | Physics step-size      | 0.005 |
# | Environment step-size  | 0.02  |
# +------------------------+-------+
#
# [INFO] <EventManager> contains 2 active terms.
# +-------------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +--------+----------------------------+
# | Index  | Name                       |
# +--------+----------------------------+
# |   0    | reset_base                 |
# |   1    | reset_robot_joints         |
# |   2    | randomize_terrain          |
# +--------+----------------------------+
# +---------------------------------------+
# | Active Event Terms in Mode: 'startup' |
# +-----------+---------------------------+
# |   Index   | Name                      |
# +-----------+---------------------------+
# |     0     | foot_friction             |
# |     1     | encoder_bias              |
# |     2     | base_com                  |
# +-----------+---------------------------+
# +-----------------------------+
# | Domain Randomization Fields |
# +-------+---------------------+
# | Index | Field Name          |
# +-------+---------------------+
# |   0   | geom_friction       |
# |   1   | body_ipos           |
# |   2   | body_subtreemass    |
# |   3   | dof_invweight0      |
# |   4   | body_invweight0     |
# |   5   | tendon_length0      |
# |   6   | tendon_invweight0   |
# |   7   | actuator_acc0       |
# +-------+---------------------+
#
# [INFO] <CommandManager> contains 1 active terms.
# +----------------------------------------+
# |          Active Command Terms          |
# +-------+-------+------------------------+
# | Index | Name  |          Type          |
# +-------+-------+------------------------+
# |   0   | twist | UniformVelocityCommand |
# +-------+-------+------------------------+
#
# [INFO] <ActionManager> contains 1 active terms.
# +---------------------------------+
# | Active Action Terms (shape: 29) |
# +-------+-----------+-------------+
# | Index | Name      |   Dimension |
# +-------+-----------+-------------+
# |   0   | joint_pos |          29 |
# +-------+-----------+-------------+
#
# [INFO] <ObservationManager> contains 2 groups.
# +-----------------------------------------------------------+
# | Active Observation Terms in Group: 'actor' (shape: (99,)) |
# +-----------+----------------------------------+------------+
# |   Index   | Name                             |   Shape    |
# +-----------+----------------------------------+------------+
# |     0     | base_lin_vel                     |    (3,)    |
# |     1     | base_ang_vel                     |    (3,)    |
# |     2     | projected_gravity                |    (3,)    |
# |     3     | joint_pos                        |   (29,)    |
# |     4     | joint_vel                        |   (29,)    |
# |     5     | actions                          |   (29,)    |
# |     6     | command                          |    (3,)    |
# +-----------+----------------------------------+------------+
# +-------------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (111,)) |
# +-----------+------------------------------------+------------+
# |   Index   | Name                               |   Shape    |
# +-----------+------------------------------------+------------+
# |     0     | base_lin_vel                       |    (3,)    |
# |     1     | base_ang_vel                       |    (3,)    |
# |     2     | projected_gravity                  |    (3,)    |
# |     3     | joint_pos                          |   (29,)    |
# |     4     | joint_vel                          |   (29,)    |
# |     5     | actions                            |   (29,)    |
# |     6     | command                            |    (3,)    |
# |     7     | foot_height                        |    (2,)    |
# |     8     | foot_air_time                      |    (2,)    |
# |     9     | foot_contact                       |    (2,)    |
# |     10    | foot_contact_forces                |    (6,)    |
# +-----------+------------------------------------+------------+
#
# [INFO] <TerminationManager> contains 2 active terms.
# +------------------------------+
# |   Active Termination Terms   |
# +-------+-----------+----------+
# | Index | Name      | Time Out |
# +-------+-----------+----------+
# |   0   | time_out  |   True   |
# |   1   | fell_over |  False   |
# +-------+-----------+----------+
#
# [INFO] <RewardManager> contains 14 active terms.
# +-----------------------------------------+
# |           Active Reward Terms           |
# +-------+------------------------+--------+
# | Index | Name                   | Weight |
# +-------+------------------------+--------+
# |   0   | track_linear_velocity  |    2.0 |
# |   1   | track_angular_velocity |    2.0 |
# |   2   | upright                |    1.0 |
# |   3   | pose                   |    1.0 |
# |   4   | body_ang_vel           |  -0.05 |
# |   5   | angular_momentum       |  -0.02 |
# |   6   | dof_pos_limits         |   -1.0 |
# |   7   | action_rate_l2         |   -0.1 |
# |   8   | air_time               |    0.0 |
# |   9   | foot_clearance         |   -2.0 |
# |   10  | foot_swing_height      |  -0.25 |
# |   11  | foot_slip              |   -0.1 |
# |   12  | soft_landing           | -1e-05 |
# |   13  | self_collisions        |   -1.0 |
# +-------+------------------------+--------+
#
# [INFO] <NullCurriculumManager> (inactive)
# [INFO] <MetricsManager> contains 1 active terms.
# +-------------------------+
# |   Active Metrics Terms  |
# +-------+-----------------+
# | Index | Name            |
# +-------+-----------------+
# |   0   | mean_action_acc |
# +-------+-----------------+
#
# [INFO] <NullRecorderManager> (inactive)
# Module mujoco_warp._src.io cb0c74e load on device 'cuda:0' took 2.43 ms  (cached)
# Module _tile_cholesky_factorize_block__locals__kernel_d4231e6f 8646b2f load on device 'cuda:0' took 37.75 ms  (cached)
# Module _tile_cholesky_solve_block__locals__kernel_dcd40028 a676a8a load on device 'cuda:0' took 38.93 ms  (cached)
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 actor :  ('actor',)
# 	 critic :  ('critic',)
# --------------------------------------------------------------------------------
# Actor Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (distribution): GaussianDistribution()
#   (mlp): MLP(
#     (0): Linear(in_features=99, out_features=512, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=29, bias=True)
#   )
# )
# Critic Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (mlp): MLP(
#     (0): Linear(in_features=111, out_features=512, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#   )
# )
# ✓ โหลด policy จาก model_2999.pt

# %%
# rollout: ให้ policy สั่งหุ่น 200 step แล้วเก็บเฟรมเป็นวิดีโอ
obs = wrapped.get_observations()
frames = []
for step in range(200):
  with torch.inference_mode():
    action = policy(obs)
  obs, _, _, _ = wrapped.step(action)
  frames.append(eval_env.render())  # rgb array (H, W, 3)

VIDEO_PATH = os.path.join(LOG_ROOT, 'g1_walk.mp4')
out = VIDEO_PATH
imageio.mimsave(out, frames, fps=30)
print(f"✓ อัดวิดีโอ {len(frames)} เฟรม -> {out}")
# Out:
# ✓ อัดวิดีโอ 200 เฟรม -> /content/drive/MyDrive/mjlab_logs/g1_walk.mp4

# %%
from IPython.display import Video

Video(VIDEO_PATH, embed=True, width=480)
# Out:
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## 7) ⬇️ ดาวน์โหลดโมเดลไปใช้งาน
#
# ไฟล์ `.pt` นี้คือ **โมเดลที่ใช้งานได้จริง** — เอาไปโหลดที่เครื่องอื่น
# (ที่มี mjlab) แล้วสั่งหุ่นด้วย `play --checkpoint-file <ไฟล์>` ได้เลย

# %%
from google.colab import files

print("กำลังดาวน์โหลด:", checkpoint)
files.download(checkpoint)
# Out:
# กำลังดาวน์โหลด: /content/drive/MyDrive/mjlab_logs/g1_velocity/2026-09-10_09-03-32/model_2999.pt

# %% [markdown]
# ## 8) สรุป + ทำต่อ
#
# คุณเพิ่ง**เทรนโมเดล RL จริง**และได้ไฟล์ `.pt` ไปใช้งาน 🎉
#
# **เอาโมเดลไปใช้ที่เครื่องตัวเอง** (ที่มี mjlab):
# ```bash
# uv run play Mjlab-Velocity-Flat-Unitree-G1 --checkpoint-file model.pt
# ```
#
# **อยากให้หุ่นเดินสวยขึ้น?** เพิ่ม `--agent.max-iterations` เป็น 3000–10000
# (นานขึ้นแต่ผลดีขึ้นมาก) แล้วเทรนใหม่
#
# **อยากเทรนงานหยิบของแทน?** เปลี่ยน task เป็น `Mjlab-Lift-Cube-G1`
# (experiment_name = `g1_lift_cube`) แล้วแก้ path ใน cell ที่ 5 ตามนั้น
#
# **เข้าใจว่าข้างในทำงานยังไง?** กลับไปดู `explore_g1_velocity.ipynb` และ
# `explore_g1_manipulation.ipynb` ที่แกะ MDP ทีละส่วน
